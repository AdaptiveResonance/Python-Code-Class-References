# %%
#required libs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=np.linspace(0, 2*np.pi, 400)
y=np.sin(x**2)

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_title('A single plot')
# Out:
# Text(0.5, 1.0, 'A single plot')

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x,y)
axs[1].plot(x,-y)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x,y)
ax2.plot(x,-y)

# %%
data = pd.read_csv('M8stores.csv')

# %%
data.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs  Toronto           21.0
# 1    STR102      Apparel Zone       Apparel  Toronto           21.0
# 2    STR103       Super Bazar  Super Market  Toronto           22.8
# 3    STR104      Super Market  Super Market  Toronto           21.4
# 4    STR105     Central Store  Super Market  Toronto           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 0          16.46         0               1       4             4
# ...

# %%
# create scatter plot
plt.scatter(data['Total_Customers'],data['TotalSales'])
plt.show()

# %%
plt.plot([1,2,3,4])
plt.ylabel('Some numbers')
plt.show()

# %%
iris=pd.read_csv('M8iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width','class'])

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
colors={'Setosa': 'r', 'Versicolor': 'g','Virginica':'b'}
fig, ax=plt.subplots()
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i], color=colors[iris['class'][i]])
    
#set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
import math
plt.plot([x*0.01 for x in range(0, 1000)], [math.sin(x*0.01) for x in range(0, 1000)])
plt.show()

# %%
plt.plot(data['Total_Customers'], data['TotalSales'])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
t=np.arange(0.,5.,0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t,t**3,'g^')
plt.show()

# %%
df_1=[[1,2,5], [5,7,2,2,5],[7,2,5]]
print(df_1)
# Out:
# [[1, 2, 5], [5, 7, 2, 2, 5], [7, 2, 5]]

# %%
ticks = ['A', 'B','C']
plt.figure()

# %%
pbl=plt.boxplot(df_1,positions=np.array(range(len(df_1)))*2.0-0.4, sym='', widths=0.6)
plt.xticks(range(0, len(ticks)*2, 2), ticks)
plt.show()

# %%
#Here is a boxplot representing five trials of 10
# observations of a uniform random variable on [0,1]
df=pd.DataFrame(np.random.rand(10,5), columns=["A", "B", "C", "D","E"])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
data_iris=[iris['class'].value_counts()[i] for i in range(0,3)]
print(data_iris)
print(iris['class'].unique())
# Out:
# [50, 50, 50]
# ['Setosa' 'Versicolor' 'Virginica']

# %%
plt.bar(iris['class'].unique(), data_iris)
plt.title('Chart title')
plt.xlabel('X axix title')
plt.ylabel('Y axix title')
plt.show()

# %%
df2=pd.DataFrame(np.random.rand(10,4), columns=["A", "B", "C", "D"])
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
plt.barh(iris['class'].unique(), data_iris)
plt.title('Chart title')
plt.xlabel('X axix title')
plt.ylabel('Y axix title')
plt.show()

# %%
plt.pie(data_iris, labels=iris['class'].unique(), wedgeprops={'edgecolor':'black'})
plt.show()

# %%
slices=[59219,55466,47544,36443,35917]
labels=['JavaScript', 'HTML/CSS', 'SQL', 'Python','Java']
explode=[0,0,0,0.1,0]
plt.pie(slices, labels=labels, explode=explode, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x21a407c4ca0>,
# ...
#  [Text(0.7718391274789096, 0.7837501906172628, 'JavaScript'),
#   Text(-0.7563043225037828, 0.7987513829484705, 'HTML/CSS'),
#   Text(-0.9279786422142811, -0.5906400253912187, 'SQL'),
#   Text(0.14456175184245185, -1.191260634749693, 'Python'),
#   Text(0.9751875080557701, -0.5089295866148649, 'Java')])

# %%
data=np.random.random((12,12))
print(data)
# Out:
# [[0.14852729 0.04703083 0.03199889 0.92638053 0.24416932 0.08998533
#   0.58812681 0.92504502 0.13195589 0.57720708 0.60114185 0.20482041]
#  [0.4573921  0.17634637 0.10861991 0.2856867  0.85842223 0.08522297
#   0.07925051 0.64594124 0.31595834 0.49566274 0.95660507 0.20492276]
#  [0.0313108  0.1068602  0.86372149 0.30504591 0.31288799 0.78091822
#   0.92509203 0.54925169 0.67425141 0.31505712 0.30515588 0.94561156]
#  [0.88612341 0.62476668 0.59558646 0.65370001 0.45053372 0.39061374
#   0.1745453  0.41062945 0.14812698 0.29780864 0.27708487 0.33343618]
#  [0.84504706 0.4532312  0.24915042 0.73502746 0.74260556 0.65947531
#   0.99742332 0.1670975  0.87986585 0.65778062 0.28658291 0.93057962]
#  [0.24242233 0.92780567 0.50143941 0.18748122 0.62245421 0.6458471
#   0.34580005 0.87297756 0.67083157 0.24684478 0.70804093 0.82574542]
#  [0.85510922 0.00494736 0.8209052  0.66911937 0.7059337  0.87827835
#   0.8764698  0.84011718 0.40014739 0.5341818  0.16070222 0.4222602 ]
# ...

# %%
plt.imshow(data,cmap='hot', interpolation='nearest')
plt.title("2 D Heat Map")
plt.show()

# %%
plt.hist(iris['sepal_length'])
plt.show()
